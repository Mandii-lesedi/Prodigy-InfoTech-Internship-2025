# %%
# !pip install matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize survival count
sns.countplot(x="Survived", data=df)
plt.title('Survival Count')
plt.show()


numeric_df = df.select_dtypes(include=['number'])
sns.heatmap(numeric_df.corr(), annot=True, cmap='RdYlGn', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_df = df.select_dtypes(include=['int64', 'float64'])
correlations = numeric_df.corr()
sns.heatmap(correlations, annot=True, cmap='coolwarm', linewidths=0.5)
#survived vs sex isnt shown -  beacause sex is still a string (not numeric)
df['Sex'] = df['Sex'].map({'male':0, 'female':1})
plt.title('Correlation Heatmap with sex included')
plt.show()

# %%
#what the heatmap correlation reveals is that sex has a strong negative correlation (of about -0.54) with survived meaning more females survied 
Fare has a weak to moderate postive correlation (~ 0.26) with survived, meaning the passengers who paid a higher fare price were more likely to survive.
Pclass has a moderate negative correlation (~-0.34) meaning passengers in lower class were less likely to survive
